# %%
import pandas as pd
import requests
import os
import zipfile
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

diretorio_atual = os.getcwd()
os.chdir(f"{diretorio_atual}/dados_cvm")

# %%
anos = range(2010, 2023)

url_base = "https://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/"

for ano in anos:
    
    download = requests.get(url_base + f"dfp_cia_aberta_{ano}.zip")
    
    open(f"dfp_cia_aberta_{ano}.zip", "wb").write(download.content)

# %%
lista_demontracoes_2010_2022 = []

diretorio_atual = os.getcwd()

for arquivo in os.listdir(diretorio_atual):
    
    if arquivo == ".ipynb_checkpoints":
        
        pass
    
    elif arquivo == '.env':
        
        pass
    
    else:
        
        arquivo_zip = zipfile.ZipFile(arquivo)
        
        for planilha in arquivo_zip.namelist():
            
            demonstracao = pd.read_csv(arquivo_zip.open(planilha), sep = ";", encoding = 'ISO-8859-1',
                                      dtype = {"ORDEM_EXERC": "category"})
            
            lista_demontracoes_2010_2022.append(demonstracao)

# %%
base_dados = pd.concat(lista_demontracoes_2010_2022)

base_dados
# Out:
#                  CNPJ_CIA    DT_REFER  VERSAO                 DENOM_CIA  \
# 0      00.000.000/0001-91  2015-12-31       1           BCO BRASIL S.A.
# 1      00.000.000/0001-91  2015-12-31       2           BCO BRASIL S.A.
# 2      00.000.000/0001-91  2015-12-31       3           BCO BRASIL S.A.
# 3      00.000.208/0001-00  2015-12-31       1  BRB BCO DE BRASILIA S.A.
# 4      00.000.208/0001-00  2015-12-31       2  BRB BCO DE BRASILIA S.A.
# ...                   ...         ...     ...                       ...
# 54423  97.837.181/0001-47  2011-12-31       1              DURATEX S.A.
# 54424  97.837.181/0001-47  2011-12-31       1              DURATEX S.A.
# 54425  97.837.181/0001-47  2011-12-31       1              DURATEX S.A.
# 54426  97.837.181/0001-47  2011-12-31       1              DURATEX S.A.
# 54427  97.837.181/0001-47  2011-12-31       1              DURATEX S.A.
#
#        CD_CVM CATEG_DOC   ID_DOC    DT_RECEB  \
# 0        1023       DFP  53614.0  2016-02-25
# 1        1023       DFP  54536.0  2016-03-28
# 2        1023       DFP  57534.0  2016-06-02
# 3       14206       DFP  54309.0  2016-03-22
# 4       14206       DFP  54347.0  2016-03-23
# ...       ...       ...      ...         ...
# 54423   21091       NaN      NaN         NaN
# 54424   21091       NaN      NaN         NaN
# 54425   21091       NaN      NaN         NaN
# 54426   21091       NaN      NaN         NaN
# 54427   21091       NaN      NaN         NaN
#
#                                                 LINK_DOC  \
# 0      http://www.rad.cvm.gov.br/ENETCONSULTA/frmDown...
# 1      http://www.rad.cvm.gov.br/ENETCONSULTA/frmDown...
# 2      http://www.rad.cvm.gov.br/ENETCONSULTA/frmDown...
# 3      http://www.rad.cvm.gov.br/ENETCONSULTA/frmDown...
# 4      http://www.rad.cvm.gov.br/ENETCONSULTA/frmDown...
# ...                                                  ...
# 54423                                                NaN
# 54424                                                NaN
# 54425                                                NaN
# 54426                                                NaN
# 54427                                                NaN
#
#                                               GRUPO_DFP MOEDA ESCALA_MOEDA  \
# 0                                                   NaN   NaN          NaN
# 1                                                   NaN   NaN          NaN
# 2                                                   NaN   NaN          NaN
# 3                                                   NaN   NaN          NaN
# 4                                                   NaN   NaN          NaN
# ...                                                 ...   ...          ...
# 54423  DF Individual - Demonstração de Valor Adicionado  REAL          MIL
# 54424  DF Individual - Demonstração de Valor Adicionado  REAL          MIL
# 54425  DF Individual - Demonstração de Valor Adicionado  REAL          MIL
# 54426  DF Individual - Demonstração de Valor Adicionado  REAL          MIL
# 54427  DF Individual - Demonstração de Valor Adicionado  REAL          MIL
#
#       ORDEM_EXERC DT_FIM_EXERC    CD_CONTA  \
# 0             NaN          NaN         NaN
# 1             NaN          NaN         NaN
# 2             NaN          NaN         NaN
# 3             NaN          NaN         NaN
# 4             NaN          NaN         NaN
# ...           ...          ...         ...
# 54423      ÚLTIMO   2011-12-31  7.08.04.02
# 54424   PENÚLTIMO   2010-12-31  7.08.04.03
# 54425      ÚLTIMO   2011-12-31  7.08.04.03
# 54426   PENÚLTIMO   2010-12-31     7.08.05
# 54427      ÚLTIMO   2011-12-31     7.08.05
#
#                                    DS_CONTA  VL_CONTA ST_CONTA_FIXA  \
# 0                                       NaN       NaN           NaN
# 1                                       NaN       NaN           NaN
# 2                                       NaN       NaN           NaN
# 3                                       NaN       NaN           NaN
# 4                                       NaN       NaN           NaN
# ...                                     ...       ...           ...
# 54423                            Dividendos    3865.0             S
# 54424  Lucros Retidos / Prejuízo do Período  312208.0             S
# 54425  Lucros Retidos / Prejuízo do Período  246012.0             S
# 54426                                Outros       0.0             S
# 54427                                Outros       0.0             S
#
#       DT_INI_EXERC COLUNA_DF
# 0              NaN       NaN
# 1              NaN       NaN
# 2              NaN       NaN
# 3              NaN       NaN
# 4              NaN       NaN
# ...            ...       ...
# 54423   2011-01-01       NaN
# 54424   2010-01-01       NaN
# 54425   2011-01-01       NaN
# 54426   2010-01-01       NaN
# 54427   2011-01-01       NaN
#
# [13331089 rows x 20 columns]

# %%
base_dados
# Out:
#                  CNPJ_CIA    DT_REFER  VERSAO                 DENOM_CIA  \
# 0      00.000.000/0001-91  2015-12-31       1           BCO BRASIL S.A.
# 1      00.000.000/0001-91  2015-12-31       2           BCO BRASIL S.A.
# 2      00.000.000/0001-91  2015-12-31       3           BCO BRASIL S.A.
# 3      00.000.208/0001-00  2015-12-31       1  BRB BCO DE BRASILIA S.A.
# 4      00.000.208/0001-00  2015-12-31       2  BRB BCO DE BRASILIA S.A.
# ...                   ...         ...     ...                       ...
# 54423  97.837.181/0001-47  2011-12-31       1              DURATEX S.A.
# 54424  97.837.181/0001-47  2011-12-31       1              DURATEX S.A.
# 54425  97.837.181/0001-47  2011-12-31       1              DURATEX S.A.
# 54426  97.837.181/0001-47  2011-12-31       1              DURATEX S.A.
# 54427  97.837.181/0001-47  2011-12-31       1              DURATEX S.A.
#
#        CD_CVM CATEG_DOC   ID_DOC    DT_RECEB  \
# 0        1023       DFP  53614.0  2016-02-25
# 1        1023       DFP  54536.0  2016-03-28
# 2        1023       DFP  57534.0  2016-06-02
# 3       14206       DFP  54309.0  2016-03-22
# 4       14206       DFP  54347.0  2016-03-23
# ...       ...       ...      ...         ...
# 54423   21091       NaN      NaN         NaN
# 54424   21091       NaN      NaN         NaN
# 54425   21091       NaN      NaN         NaN
# 54426   21091       NaN      NaN         NaN
# 54427   21091       NaN      NaN         NaN
#
#                                                 LINK_DOC  \
# 0      http://www.rad.cvm.gov.br/ENETCONSULTA/frmDown...
# 1      http://www.rad.cvm.gov.br/ENETCONSULTA/frmDown...
# 2      http://www.rad.cvm.gov.br/ENETCONSULTA/frmDown...
# 3      http://www.rad.cvm.gov.br/ENETCONSULTA/frmDown...
# 4      http://www.rad.cvm.gov.br/ENETCONSULTA/frmDown...
# ...                                                  ...
# 54423                                                NaN
# 54424                                                NaN
# 54425                                                NaN
# 54426                                                NaN
# 54427                                                NaN
#
#                                               GRUPO_DFP MOEDA ESCALA_MOEDA  \
# 0                                                   NaN   NaN          NaN
# 1                                                   NaN   NaN          NaN
# 2                                                   NaN   NaN          NaN
# 3                                                   NaN   NaN          NaN
# 4                                                   NaN   NaN          NaN
# ...                                                 ...   ...          ...
# 54423  DF Individual - Demonstração de Valor Adicionado  REAL          MIL
# 54424  DF Individual - Demonstração de Valor Adicionado  REAL          MIL
# 54425  DF Individual - Demonstração de Valor Adicionado  REAL          MIL
# 54426  DF Individual - Demonstração de Valor Adicionado  REAL          MIL
# 54427  DF Individual - Demonstração de Valor Adicionado  REAL          MIL
#
#       ORDEM_EXERC DT_FIM_EXERC    CD_CONTA  \
# 0             NaN          NaN         NaN
# 1             NaN          NaN         NaN
# 2             NaN          NaN         NaN
# 3             NaN          NaN         NaN
# 4             NaN          NaN         NaN
# ...           ...          ...         ...
# 54423      ÚLTIMO   2011-12-31  7.08.04.02
# 54424   PENÚLTIMO   2010-12-31  7.08.04.03
# 54425      ÚLTIMO   2011-12-31  7.08.04.03
# 54426   PENÚLTIMO   2010-12-31     7.08.05
# 54427      ÚLTIMO   2011-12-31     7.08.05
#
#                                    DS_CONTA  VL_CONTA ST_CONTA_FIXA  \
# 0                                       NaN       NaN           NaN
# 1                                       NaN       NaN           NaN
# 2                                       NaN       NaN           NaN
# 3                                       NaN       NaN           NaN
# 4                                       NaN       NaN           NaN
# ...                                     ...       ...           ...
# 54423                            Dividendos    3865.0             S
# 54424  Lucros Retidos / Prejuízo do Período  312208.0             S
# 54425  Lucros Retidos / Prejuízo do Período  246012.0             S
# 54426                                Outros       0.0             S
# 54427                                Outros       0.0             S
#
#       DT_INI_EXERC COLUNA_DF
# 0              NaN       NaN
# 1              NaN       NaN
# 2              NaN       NaN
# 3              NaN       NaN
# 4              NaN       NaN
# ...            ...       ...
# 54423   2011-01-01       NaN
# 54424   2010-01-01       NaN
# 54425   2011-01-01       NaN
# 54426   2010-01-01       NaN
# 54427   2011-01-01       NaN
#
# [13331089 rows x 20 columns]

# %%
base_dados[['con_ind', 'tipo_dem']] = base_dados['GRUPO_DFP'].str.split("-", expand = True)
base_dados['con_ind'] = base_dados['con_ind'].str.strip()
base_dados['tipo_dem'] = base_dados['tipo_dem'].str.strip()

base_dados = base_dados[base_dados['ORDEM_EXERC'] != "PENÚLTIMO"]

# %%
lista_dem = base_dados['tipo_dem'].unique()

# %%
lista_empresas = base_dados['DENOM_CIA'].unique()

# %%
weg_dre = base_dados[(base_dados["DENOM_CIA"] == "WEG S.A.") & 
                     (base_dados["tipo_dem"] == "Demonstração do Resultado") &
                    (base_dados["DS_CONTA"] == "Receita de Venda de Bens e/ou Serviços") &
                    (base_dados["con_ind"] == "DF Consolidado")]

weg_dre = weg_dre[['DT_REFER', 'VL_CONTA']]

weg_dre
